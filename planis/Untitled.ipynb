# %%
import planis.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import planis.py
#
# ModuleNotFoundError: No module named 'planis.py'; 'planis' is not a package
